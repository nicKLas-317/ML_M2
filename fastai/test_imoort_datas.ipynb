# %%
from fastai.vision import *
path = untar_data(URLs.MNIST_SAMPLE)
data = ImageDataBunch.from_folder(path)
learn = cnn_learner(data, models.resnet18)

# %%
learn.fit_one_cycle(2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.226643</td>
#       <td>0.129158</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.112493</td>
#       <td>0.090805</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.read_csv(path/'labels.csv')
data_mnist = ImageList.from_df(df=df, path=path)
data_mnist
# Out:
# ImageList (14434 items)
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# Path: /root/.fastai/data/mnist_sample

# %%
# Exemple sur un IMDB
from fastai.text import *
imdb = untar_data(URLs.IMDB_SAMPLE)

import pandas as pd
text = pd.read_csv(imdb/"texts.csv")
text
# Out:
#         label                                               text  is_valid
# 0    negative  Un-bleeping-believable! Meg Ryan doesn't even ...     False
# 1    positive  This is a extremely well-made film. The acting...     False
# 2    negative  Every once in a long while a movie will come a...     False
# 3    positive  Name just says it all. I watched this movie wi...     False
# 4    negative  This movie succeeds at being one of the most u...     False
# ..        ...                                                ...       ...
# 995  negative  There are many different versions of this one ...      True
# 996  positive  Once upon a time Hollywood produced live-actio...      True
# 997  negative  Wenders was great with Million $ Hotel.I don't...      True
# 998  negative  Although a film with Bruce Willis is always wo...      True
# 999  positive  A compelling, honest, daring, and unforgettabl...      True
#
# [1000 rows x 3 columns]

# %%
# !pip install kaggle

# %%
# !pip install kaggle

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-87d439f2-743d-4d08-8b7d-f37ab4aecc35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87d439f2-743d-4d08-8b7d-f37ab4aecc35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 70 bytes

# %%
# !kaggle datasets download "center-for-policing-equity/data-science-for-good"
# !unzip data-science-for-good.zip
import pandas as pd 

basepath = "Dept_23-00089/23-00089_ACS_data/23-00089_ACS_race-sex-age/"
rca_df = pd.read_csv(basepath + "ACS_15_5YR_DP05_with_ann.csv")
rca_df.head()
# Out:
# ...
#  87% 82.0M/94.7M [00:00<00:00, 173MB/s]
# 100% 94.7M/94.7M [00:00<00:00, 122MB/s]
# Archive:  data-science-for-good.zip
#   inflating: ACS_variable_descriptions.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_education-attainment-over-25/ACS_15_5YR_B15003_metadata.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_education-attainment-over-25/ACS_15_5YR_B15003_with_ann.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_education-attainment/ACS_15_5YR_S1501_metadata.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_education-attainment/ACS_15_5YR_S1501_with_ann.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_employment/ACS_15_5YR_S2301_metadata.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_employment/ACS_15_5YR_S2301_with_ann.csv
#   inflating: Dept_11-00091/11-00091_ACS_data/11-00091_ACS_income/ACS_15_5YR_S1903_metadata.csv
# ...

# %%
# !kaggle datasets download anirudhg15/bears-fastai-2021
# Out:
# ...
#  99% 270M/272M [00:02<00:00, 118MB/s]
# 100% 272M/272M [00:02<00:00, 113MB/s]

# %%
# !unzip bears-fastai-2021.zip
import pandas as pd
# Out:
# Archive:  bears-fastai-2021.zip
#   inflating: bears/black/00000000.jpg
#   inflating: bears/black/00000001.jpg
#   inflating: bears/black/00000002.jpg
#   inflating: bears/black/00000003.jpg
#   inflating: bears/black/00000004.jpg
#   inflating: bears/black/00000005.jpg
#   inflating: bears/black/00000006.jpg
#   inflating: bears/black/00000007.jpg
#   inflating: bears/black/00000008.jpg
#   inflating: bears/black/00000009.jpg
#   inflating: bears/black/00000011.jpeg
#   inflating: bears/black/00000012.jpg
#   inflating: bears/black/00000013.jpg
#   inflating: bears/black/00000014.jpg
#   inflating: bears/black/00000015.png
#   inflating: bears/black/00000016.jpg
#   inflating: bears/black/00000017.jpg
#   inflating: bears/black/00000018.jpg
#   inflating: bears/black/00000019.jpg
#   inflating: bears/black/00000020.jpg
#   inflating: bears/black/00000021.jpg
#   inflating: bears/black/00000022.jpg
#   inflating: bears/black/00000023.jpg
#   inflating: bears/black/00000024.jpg
# ...

# %%
from pathlib import Path
path = Path('../input/bears-fastai-2021/bears')
path.ls()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-8c0e293f4feb> in <module>()
#       1 from pathlib import Path
#       2 path = Path('../input/bears-fastai-2021/bears')
# ----> 3 path.ls()
#
# /usr/local/lib/python3.7/dist-packages/fastai/core.py in <lambda>(x)
#     237     return np.arange(len(x))
#     238
# --> 239 Path.ls = lambda x: list(x.iterdir())
#     240
#     241 def join_path(fname:PathOrStr, path:PathOrStr='.')->Path:
#
# /usr/lib/python3.7/pathlib.py in iterdir(self)
#    1105         if self._closed:
#    1106             self._raise_closed()
# -> 1107         for name in self._accessor.listdir(self):
#    1108             if name in {'.', '..'}:
#    1109                 # Yielding a path object for these makes little sense
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/bears-fastai-2021/bears'

# %%
rca_df = pd.read_csv(content/bears-fastai-2021)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-08b87c713060> in <module>()
# ----> 1 rca_df = pd.read_csv(content/bears-fastai-2021)
#
# NameError: name 'content' is not defined

# %%
# !ls
# Out:
# ACS_variable_descriptions.csv  Dept_11-00091  Dept_35-00103  Dept_49-00035
# bears			       Dept_23-00089  Dept_37-00027  Dept_49-00081
# bears-fastai-2021.zip	       Dept_24-00013  Dept_37-00049  sample_data
# cpe-data		       Dept_24-00098  Dept_49-00009
# data-science-for-good.zip      Dept_35-00016  Dept_49-00033

# %%
# !ls
# Out:
# black  grizzly	teddy

# %%
cd black
# Out:
# [Errno 2] No such file or directory: 'black'
# /content/bears/black

# %%
# !ls
# Out:
# 00000000.jpg   00000021.jpg   00000041.jpg  00000061.jpg   00000084.jpg
# 00000001.jpg   00000022.jpg   00000042.jpg  00000062.jpg   00000085.jpg
# 00000002.jpg   00000023.jpg   00000043.jpg  00000063.jpg   00000086.jpg
# 00000003.jpg   00000024.jpg   00000044.jpg  00000064.jpg   00000087.jpg
# 00000004.jpg   00000025.jpg   00000045.jpg  00000065.jpg   00000088.jpg
# 00000005.jpg   00000026.jpg   00000046.jpg  00000067.jpg   00000089.jpg
# 00000006.jpg   00000027.jpg   00000047.jpg  00000068.jpg   00000090.jpg
# 00000007.jpg   00000028.jpg   00000048.jpg  00000069.jpg   00000091.jpg
# 00000008.jpg   00000029.jpg   00000049.jpg  00000070.jpg   00000092.jpg
# 00000009.jpg   00000030.jpg   00000050.jpg  00000071.jpg   00000093.jpg
# 00000011.jpeg  00000031.jpg   00000051.jpg  00000072.jpg   00000094.jpg
# 00000012.jpg   00000032.jpg   00000052.jpg  00000074.jpg   00000095.jpeg
# 00000013.jpg   00000033.jpg   00000053.jpg  00000075.jpg   00000096.jpg
# ...

# %%
path = Path('../input/bears-fastai-2021/bears')
path.ls()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-d541e6ffcf3a> in <module>()
#       1 path = Path('../input/bears-fastai-2021/bears')
# ----> 2 path.ls()
#
# /usr/local/lib/python3.7/dist-packages/fastai/core.py in <lambda>(x)
#     237     return np.arange(len(x))
#     238
# --> 239 Path.ls = lambda x: list(x.iterdir())
#     240
#     241 def join_path(fname:PathOrStr, path:PathOrStr='.')->Path:
#
# /usr/lib/python3.7/pathlib.py in iterdir(self)
#    1105         if self._closed:
#    1106             self._raise_closed()
# -> 1107         for name in self._accessor.listdir(self):
#    1108             if name in {'.', '..'}:
#    1109                 # Yielding a path object for these makes little sense
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/bears-fastai-2021/bears'

# %%
print(fastai.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d30136f3d297> in <module>()
# ----> 1 print(fastai.__version__)
#
# NameError: name 'fastai' is not defined
